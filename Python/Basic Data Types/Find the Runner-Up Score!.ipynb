# %% [markdown]
# ## Solution:
# ```python
# if __name__ == '__main__':
#     n = int(raw_input())
#     arr = map(int, raw_input().split())
#
#     my_list = list(arr)
#     my_list.sort()
#     highest = max(my_list)
#
#     for i in range(len(my_list)-1, -1, -1):
#         if my_list[i] < highest:
#             break
#
#     print(my_list[i])
# ```
